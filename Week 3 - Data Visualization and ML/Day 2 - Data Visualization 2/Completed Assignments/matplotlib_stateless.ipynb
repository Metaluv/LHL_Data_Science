# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('GLB.Ts+dSST.csv', header=1)
df
# Out:
#      Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 0    1880 -0.17 -0.23 -0.08 -0.15 -0.09 -0.20 -0.17 -0.09 -0.13  -.23  -.21
# 1    1881 -0.18 -0.13  0.04  0.06  0.07 -0.18  0.01 -0.02 -0.14  -.20  -.17
# 2    1882  0.17  0.15  0.05 -0.16 -0.13 -0.22 -0.15 -0.06 -0.14  -.23  -.16
# 3    1883 -0.28 -0.36 -0.12 -0.18 -0.17 -0.06 -0.06 -0.13 -0.21  -.11  -.23
# 4    1884 -0.12 -0.07 -0.36 -0.39 -0.33 -0.34 -0.32 -0.27 -0.26  -.24  -.32
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 137  2017  1.02  1.14  1.16  0.95  0.91  0.72  0.82  0.87  0.77   .90   .87
# 138  2018  0.81  0.85  0.89  0.89  0.83  0.78  0.83  0.76  0.80  1.01   .82
# 139  2019  0.93  0.95  1.17  1.01  0.85  0.91  0.94  0.94  0.92  1.01  1.00
# 140  2020  1.16  1.25  1.17  1.13  1.02  0.92  0.91  0.88  0.99   .89  1.11
# 141  2021  0.81  0.64  0.89  0.76  0.79  0.85  0.92  0.82  0.92   ***   ***
#
#       Dec   J-D   D-N   DJF   MAM   JJA   SON
# 0    -.16  -.16   ***   *** -0.11 -0.15  -.19
# 1    -.06  -.07  -.08  -.16  0.06 -0.06  -.17
# 2    -.36  -.10  -.08   .09 -0.08 -0.15  -.17
# 3    -.10  -.17  -.19  -.33 -0.15 -0.09  -.18
# 4    -.30  -.28  -.26  -.10 -0.36 -0.31  -.28
# ..    ...   ...   ...   ...   ...   ...   ...
# 137   .93   .92   .92  1.01  1.01  0.80   .85
# 138   .92   .85   .85   .86  0.87  0.79   .88
# 139  1.10   .98   .96   .93  1.01  0.93   .98
# 140   .82  1.02  1.04  1.17  1.11  0.90  1.00
# 141   ***   ***   ***   .76  0.81  0.86   ***
#
# [142 rows x 19 columns]

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(20,5))
ax.plot(df['Year'], df['Jan'], label='January', c='steelblue', ls='-', lw=3, marker='.', ms=7, mfc='#50514F', zorder=2)
ax.plot(df['Year'], df['Aug'], label='August', c='#F25F5C', ls='--', lw=3, zorder=2)

# store legend in leg
leg = ax.legend(loc=2, ncol=2, numpoints=1, fontsize=15, shadow=True)

# create 0 line
ax.axhline(0, lw=2, c='dimgray', ls='-', alpha=0.5, zorder=1)

# customize ax, leg, and fig
ax.set_ylabel('Temperature\nAnomaly [$^o$C]', fontsize=20)
ax.set_xlabel('Year', fontsize=20)
ax.set_title('Yearly Temperature Anomaly Means for January and August', fontsize=24, y=1.05)
xticklabels = np.arange(1880, 2030, 10) 

# plot extends to year 2020 for extra white space on the right side
ax.xaxis.set_ticks(xticklabels)
ax.set_xticklabels(xticklabels, fontsize=15, rotation=45)
yticklabels = np.arange(-1.5, 2, 0.5)
ax.yaxis.set_ticks(yticklabels)
ax.set_yticklabels(yticklabels, fontsize=15)
ax.set_xlim([1880, 2030])
ax.set_ylim([-1.5, 1.5])
ax.grid()
leg.set_title(title='Month', prop = {'size':15})
fig.patch.set_facecolor('lightsteelblue')

# %%
fig.savefig('jan_aug_tempanom.png', dpi=150, bbox_inches='tight', format='png', facecolor=fig.get_facecolor())
