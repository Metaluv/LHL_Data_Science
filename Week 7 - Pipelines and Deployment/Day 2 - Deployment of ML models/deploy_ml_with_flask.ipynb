# %%
import pandas as pd
from sklearn.datasets import load_wine
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest
from sklearn.ensemble import RandomForestClassifier
import pickle

# %%
data = load_wine()
df = pd.DataFrame(data['data'])
df.columns = data['feature_names']
y=data['target']
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# 0                          3.92   1065.0
# 1                          3.40   1050.0
# 2                          3.17   1185.0
# 3                          3.45   1480.0
# 4                          2.93    735.0

# %%
class RawFeats:
    def __init__(self, feats):
        self.feats = feats
        
    def fit(self, X, y=None):
        pass
    
    def transform(self, X, y=None):
        return X[self.feats]
    
    def fit_transform(self, X, y=None):
        self.fit(X)
        return self.transform(X)
    
# features we want to keep for PCA
feats = ['alcohol','malic_acid','ash','alcalinity_of_ash','magnesium',
         'total_phenols','flavanoids','nonflavanoid_phenols']
# creating class object with indexes we want to keep.
raw_feats = RawFeats(feats)

# %%
sc = StandardScaler()
pca = PCA(n_components=2)

# %%
selection = SelectKBest(k=4)

# %%
rf = RandomForestClassifier()

# %%
PCA_pipeline = Pipeline([
    ('rawFeats', raw_feats),
    ('scaler', sc),
    ('pca', pca)
])

kbest_pipeline = Pipeline([('kBest', selection)])

# %%
all_features = FeatureUnion([
    ('pcaPipeline', PCA_pipeline),
    ('kBestPipeline', kbest_pipeline)
])

# %%
main_pipeline = Pipeline([
    ('features', all_features),
    ('rf', rf)
])

# %%
param_grid = {'features__pcaPipeline__pca__n_components': [1, 2, 3],
              'features__kBestPipeline__kBest__k': [1, 2, 3],
              'rf__n_estimators': [2,5,10],
              'rf__max_depth': [2,4,6]
             }

grid_search = GridSearchCV(main_pipeline, param_grid, n_jobs=-1, verbose=1, refit=True)

grid_search.fit(df, y)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# GridSearchCV(estimator=Pipeline(steps=[('features',
#                                         FeatureUnion(transformer_list=[('pcaPipeline',
#                                                                         Pipeline(steps=[('rawFeats',
#                                                                                          <__main__.RawFeats object at 0x7f0d6e44b130>),
#                                                                                         ('scaler',
#                                                                                          StandardScaler()),
#                                                                                         ('pca',
#                                                                                          PCA(n_components=2))])),
#                                                                        ('kBestPipeline',
#                                                                         Pipeline(steps=[('kBest',
#                                                                                          SelectKBest(k=4))]))])),
#                                        ('rf', RandomForestClassifier())]),
#              n_jobs=-1,
#              param_grid={'features__kBestPipeline__kBest__k': [1, 2, 3],
#                          'features__pcaPipeline__pca__n_components': [1, 2, 3],
#                          'rf__max_depth': [2, 4, 6],
#                          'rf__n_estimators': [2, 5, 10]},
#              verbose=1)

# %%
print(grid_search.best_params_)
# Out:
# {'features__kBestPipeline__kBest__k': 3, 'features__pcaPipeline__pca__n_components': 2, 'rf__max_depth': 6, 'rf__n_estimators': 10}

# %%
pickle.dump(grid_search, open('model.p','wb'))
# Out:
# [CV 1/5; 64/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=2, rf__n_estimators=2;, score=0.722 total time=   0.0s
# [CV 1/5; 77/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=4, rf__n_estimators=5
# [CV 1/5; 77/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=4, rf__n_estimators=5;, score=0.806 total time=   0.0s
# [CV 2/5; 77/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=4, rf__n_estimators=5
# [CV 2/5; 77/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=4, rf__n_estimators=5;, score=0.972 total time=   0.0s
# [CV 3/5; 77/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=4, rf__n_estimators=5
# [CV 3/5; 77/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=4, rf__n_estimators=5;, score=0.806 total time=   0.0s
# [CV 4/5; 77/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=4, rf__n_estimators=5
# [CV 4/5; 77/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=4, rf__n_estimators=5;, score=0.971 total time=   0.0s
# [CV 5/5; 77/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=4, rf__n_estimators=5
# [CV 5/5; 77/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=4, rf__n_estimators=5;, score=0.971 total time=   0.0s
# [CV 1/5; 78/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=4, rf__n_estimators=10
# [CV 1/5; 78/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=4, rf__n_estimators=10;, score=0.778 total time=   0.1s
# [CV 2/5; 78/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=4, rf__n_estimators=10
# [CV 2/5; 78/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=4, rf__n_estimators=10;, score=0.917 total time=   0.0s
# [CV 3/5; 78/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=4, rf__n_estimators=10
# [CV 3/5; 78/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=4, rf__n_estimators=10;, score=0.861 total time=   0.0s
# [CV 5/5; 81/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=6, rf__n_estimators=10
# [CV 5/5; 81/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=6, rf__n_estimators=10;, score=1.000 total time=   0.0s
#
# [CV 5/5; 64/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=2, rf__n_estimators=2;, score=1.000 total time=   0.0s
# [CV 1/5; 65/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=2, rf__n_estimators=5
# [CV 1/5; 65/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=2, rf__n_estimators=5;, score=0.833 total time=   0.1s
# [CV 2/5; 65/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=2, rf__n_estimators=5
# [CV 2/5; 65/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=2, rf__n_estimators=5;, score=0.806 total time=   0.1s
# [CV 3/5; 65/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=2, rf__n_estimators=5
# [CV 3/5; 65/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=2, rf__n_estimators=5;, score=0.778 total time=   0.0s
# [CV 4/5; 65/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=2, rf__n_estimators=5
# [CV 4/5; 65/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=2, rf__n_estimators=5;, score=0.943 total time=   0.0s
# [CV 4/5; 70/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=6, rf__n_estimators=2
# [CV 4/5; 70/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=6, rf__n_estimators=2;, score=0.886 total time=   0.0s
# [CV 5/5; 70/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=6, rf__n_estimators=2
# [CV 5/5; 70/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=6, rf__n_estimators=2;, score=0.943 total time=   0.0s
# [CV 1/5; 71/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=6, rf__n_estimators=5
# [CV 1/5; 71/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=6, rf__n_estimators=5;, score=0.833 total time=   0.0s
# [CV 2/5; 71/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=6, rf__n_estimators=5
# [CV 2/5; 71/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=6, rf__n_estimators=5;, score=0.861 total time=   0.0s
# [CV 3/5; 71/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=6, rf__n_estimators=5
# [CV 3/5; 71/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=6, rf__n_estimators=5;, score=0.917 total time=   0.0s
# [CV 4/5; 71/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=6, rf__n_estimators=5
# [CV 4/5; 71/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=6, rf__n_estimators=5;, score=0.971 total time=   0.0s
# [CV 5/5; 71/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=6, rf__n_estimators=5
# [CV 5/5; 71/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=6, rf__n_estimators=5;, score=0.971 total time=   0.0s
# [CV 1/5; 72/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=6, rf__n_estimators=10
# [CV 1/5; 72/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=6, rf__n_estimators=10;, score=0.806 total time=   0.1s
# [CV 2/5; 80/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=6, rf__n_estimators=5
# [CV 2/5; 80/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=6, rf__n_estimators=5;, score=0.861 total time=   0.0s
# [CV 4/5; 80/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=6, rf__n_estimators=5
# [CV 4/5; 80/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=6, rf__n_estimators=5;, score=1.000 total time=   0.0s
# [CV 1/5; 81/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=6, rf__n_estimators=10
# [CV 1/5; 81/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=6, rf__n_estimators=10;, score=0.833 total time=   0.0s
# [CV 4/5; 81/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=6, rf__n_estimators=10
# [CV 4/5; 81/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=6, rf__n_estimators=10;, score=0.971 total time=   0.0s
#
# [CV 1/5; 67/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=4, rf__n_estimators=2;, score=0.806 total time=   0.0s
# [CV 2/5; 67/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=4, rf__n_estimators=2
# [CV 2/5; 67/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=4, rf__n_estimators=2;, score=0.806 total time=   0.0s
# [CV 3/5; 75/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=2, rf__n_estimators=10
# [CV 3/5; 75/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=2, rf__n_estimators=10;, score=0.778 total time=   0.1s
# [CV 4/5; 75/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=2, rf__n_estimators=10
# [CV 4/5; 75/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=2, rf__n_estimators=10;, score=0.971 total time=   0.0s
# [CV 5/5; 75/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=2, rf__n_estimators=10
# [CV 5/5; 75/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=2, rf__n_estimators=10;, score=1.000 total time=   0.0s
# [CV 1/5; 76/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=4, rf__n_estimators=2
# [CV 1/5; 76/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=4, rf__n_estimators=2;, score=0.806 total time=   0.0s
# [CV 2/5; 76/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=4, rf__n_estimators=2
# [CV 2/5; 76/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=4, rf__n_estimators=2;, score=0.778 total time=   0.0s
# [CV 3/5; 76/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=4, rf__n_estimators=2
# [CV 3/5; 76/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=4, rf__n_estimators=2;, score=0.778 total time=   0.0s
# [CV 4/5; 76/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=4, rf__n_estimators=2
# [CV 4/5; 76/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=4, rf__n_estimators=2;, score=0.857 total time=   0.0s
# [CV 5/5; 76/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=4, rf__n_estimators=2
# [CV 5/5; 76/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=4, rf__n_estimators=2;, score=0.886 total time=   0.0s
# [CV 3/5; 81/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=6, rf__n_estimators=10
# [CV 3/5; 81/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=6, rf__n_estimators=10;, score=0.833 total time=   0.0s
#
# [CV 3/5; 72/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=6, rf__n_estimators=10
# [CV 3/5; 72/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=6, rf__n_estimators=10;, score=0.889 total time=   0.1s
# [CV 4/5; 72/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=6, rf__n_estimators=10
# [CV 4/5; 72/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=6, rf__n_estimators=10;, score=0.971 total time=   0.0s
# [CV 5/5; 72/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=6, rf__n_estimators=10
# [CV 5/5; 72/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=6, rf__n_estimators=10;, score=1.000 total time=   0.0s
# [CV 1/5; 73/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=2, rf__n_estimators=2
# [CV 1/5; 73/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=2, rf__n_estimators=2;, score=0.806 total time=   0.0s
# [CV 2/5; 73/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=2, rf__n_estimators=2
# [CV 2/5; 73/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=2, rf__n_estimators=2;, score=0.833 total time=   0.0s
# [CV 3/5; 73/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=2, rf__n_estimators=2
# [CV 3/5; 73/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=2, rf__n_estimators=2;, score=0.806 total time=   0.0s
# [CV 4/5; 73/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=2, rf__n_estimators=2
# [CV 4/5; 73/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=2, rf__n_estimators=2;, score=0.943 total time=   0.0s
# [CV 3/5; 80/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=6, rf__n_estimators=5
# [CV 3/5; 80/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=6, rf__n_estimators=5;, score=0.889 total time=   0.0s
# [CV 5/5; 80/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=6, rf__n_estimators=5
# [CV 5/5; 80/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=6, rf__n_estimators=5;, score=0.971 total time=   0.0s
# [CV 2/5; 81/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=6, rf__n_estimators=10
# [CV 2/5; 81/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=6, rf__n_estimators=10;, score=0.917 total time=   0.0s
#
# [CV 3/5; 59/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=1, rf__max_depth=4, rf__n_estimators=5
# [CV 3/5; 59/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=1, rf__max_depth=4, rf__n_estimators=5;, score=0.861 total time=   0.0s
# [CV 4/5; 59/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=1, rf__max_depth=4, rf__n_estimators=5
# [CV 4/5; 59/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=1, rf__max_depth=4, rf__n_estimators=5;, score=0.971 total time=   0.0s
# [CV 5/5; 59/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=1, rf__max_depth=4, rf__n_estimators=5
# [CV 5/5; 59/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=1, rf__max_depth=4, rf__n_estimators=5;, score=1.000 total time=   0.0s
# [CV 1/5; 60/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=1, rf__max_depth=4, rf__n_estimators=10
# [CV 1/5; 60/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=1, rf__max_depth=4, rf__n_estimators=10;, score=0.833 total time=   0.0s
# [CV 2/5; 60/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=1, rf__max_depth=4, rf__n_estimators=10
# [CV 2/5; 60/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=1, rf__max_depth=4, rf__n_estimators=10;, score=0.889 total time=   0.0s
# [CV 3/5; 60/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=1, rf__max_depth=4, rf__n_estimators=10
# [CV 3/5; 60/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=1, rf__max_depth=4, rf__n_estimators=10;, score=0.833 total time=   0.1s
# [CV 4/5; 60/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=1, rf__max_depth=4, rf__n_estimators=10
# [CV 4/5; 60/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=1, rf__max_depth=4, rf__n_estimators=10;, score=0.971 total time=   0.1s
# [CV 5/5; 60/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=1, rf__max_depth=4, rf__n_estimators=10
# [CV 5/5; 60/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=1, rf__max_depth=4, rf__n_estimators=10;, score=1.000 total time=   0.0s
# [CV 1/5; 69/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=4, rf__n_estimators=10
# [CV 1/5; 69/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=4, rf__n_estimators=10;, score=0.833 total time=   0.0s
# [CV 2/5; 69/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=4, rf__n_estimators=10
# [CV 2/5; 69/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=4, rf__n_estimators=10;, score=0.944 total time=   0.1s
# [CV 3/5; 69/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=4, rf__n_estimators=10
# [CV 3/5; 69/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=4, rf__n_estimators=10;, score=0.861 total time=   0.0s
# [CV 4/5; 69/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=4, rf__n_estimators=10
# [CV 4/5; 69/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=4, rf__n_estimators=10;, score=0.971 total time=   0.0s
# [CV 5/5; 69/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=4, rf__n_estimators=10
# [CV 5/5; 69/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=4, rf__n_estimators=10;, score=1.000 total time=   0.0s
# [CV 1/5; 70/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=6, rf__n_estimators=2
# [CV 1/5; 70/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=6, rf__n_estimators=2;, score=0.778 total time=   0.0s
# [CV 2/5; 70/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=6, rf__n_estimators=2
# [CV 2/5; 70/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=6, rf__n_estimators=2;, score=0.833 total time=   0.0s
# [CV 3/5; 70/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=6, rf__n_estimators=2
# [CV 3/5; 70/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=6, rf__n_estimators=2;, score=0.833 total time=   0.0s
# [CV 4/5; 78/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=4, rf__n_estimators=10
# [CV 4/5; 78/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=4, rf__n_estimators=10;, score=0.971 total time=   0.1s
# [CV 5/5; 78/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=4, rf__n_estimators=10
# [CV 5/5; 78/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=4, rf__n_estimators=10;, score=0.971 total time=   0.0s
# [CV 1/5; 79/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=6, rf__n_estimators=2
# [CV 1/5; 79/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=6, rf__n_estimators=2;, score=0.861 total time=   0.0s
# [CV 2/5; 79/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=6, rf__n_estimators=2
# [CV 2/5; 79/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=6, rf__n_estimators=2;, score=0.750 total time=   0.0s
# [CV 3/5; 79/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=6, rf__n_estimators=2
# [CV 3/5; 79/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=6, rf__n_estimators=2;, score=0.778 total time=   0.0s
# [CV 4/5; 79/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=6, rf__n_estimators=2
# [CV 4/5; 79/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=6, rf__n_estimators=2;, score=0.914 total time=   0.0s
# [CV 5/5; 79/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=6, rf__n_estimators=2
# [CV 5/5; 79/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=6, rf__n_estimators=2;, score=1.000 total time=   0.0s
# [CV 1/5; 80/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=6, rf__n_estimators=5
# [CV 1/5; 80/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=6, rf__n_estimators=5;, score=0.833 total time=   0.0s
#
# [CV 1/5; 68/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=4, rf__n_estimators=5;, score=0.833 total time=   0.0s
# [CV 2/5; 68/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=4, rf__n_estimators=5
# [CV 2/5; 68/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=4, rf__n_estimators=5;, score=0.889 total time=   0.0s
# [CV 3/5; 68/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=4, rf__n_estimators=5
# [CV 3/5; 68/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=4, rf__n_estimators=5;, score=0.861 total time=   0.0s
# [CV 4/5; 68/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=4, rf__n_estimators=5
# [CV 4/5; 68/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=4, rf__n_estimators=5;, score=0.971 total time=   0.1s
# [CV 5/5; 68/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=4, rf__n_estimators=5
# [CV 5/5; 68/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=2, rf__max_depth=4, rf__n_estimators=5;, score=1.000 total time=   0.0s
# [CV 5/5; 73/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=2, rf__n_estimators=2
# [CV 5/5; 73/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=2, rf__n_estimators=2;, score=0.943 total time=   0.0s
# [CV 1/5; 74/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=2, rf__n_estimators=5
# [CV 1/5; 74/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=2, rf__n_estimators=5;, score=0.861 total time=   0.0s
# [CV 2/5; 74/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=2, rf__n_estimators=5
# [CV 2/5; 74/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=2, rf__n_estimators=5;, score=0.889 total time=   0.0s
# [CV 3/5; 74/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=2, rf__n_estimators=5
# [CV 3/5; 74/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=2, rf__n_estimators=5;, score=0.806 total time=   0.0s
# [CV 4/5; 74/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=2, rf__n_estimators=5
# [CV 4/5; 74/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=2, rf__n_estimators=5;, score=0.857 total time=   0.0s
# [CV 5/5; 74/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=2, rf__n_estimators=5
# [CV 5/5; 74/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=2, rf__n_estimators=5;, score=0.971 total time=   0.1s
# [CV 1/5; 75/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=2, rf__n_estimators=10
# [CV 1/5; 75/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=2, rf__n_estimators=10;, score=0.778 total time=   0.0s
# [CV 2/5; 75/81] START features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=2, rf__n_estimators=10
# [CV 2/5; 75/81] END features__kBestPipeline__kBest__k=3, features__pcaPipeline__pca__n_components=3, rf__max_depth=2, rf__n_estimators=10;, score=0.861 total time=   0.0s
