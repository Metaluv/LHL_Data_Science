# %%
import pandas as pd
import networkx as nx

# %% [markdown]
# we will be using networkx package http://networkx.readthedocs.io/en/networkx-1.11/index.html

# %% [markdown]
# ### Load enron dataset into pandas
# Link to Enron company https://en.wikipedia.org/wiki/Enron. You can find the data [here](https://drive.google.com/file/d/1R8TW3CUN5UM_EtQT923EtyCmICPX2NZ8/view?usp=sharing).

# %% [markdown]
# # Data cleaning and preparation

# %%
# we are using = as a separator so we don't mix text with columns separator
df_enron = pd.read_csv("data/enron.csv", sep="=")
df_enron.head()
# Out:
#    Unnamed: 0                       from  \
# 0           1   shelley.corman@enron.com
# 1           5      frank.ermis@enron.com
# 2           6    joan.veselack@enron.com
# 3           7  sharon.crawford@enron.com
# 4           9    chris.germany@enron.com
#
#                                                   to             date  \
# 0  jean.adams@enron.com, william.aldinger@enron.c...   20 Nov 2001 15
# 1                             mike.grigsby@enron.com   14 Feb 2001 02
# 2  jwhited@columbiaenergygroup.com, chris.germany...   22 Mar 2000 08
# 3  chris.gaffney@enron.com, mark.powell@enron.com...   27 Oct 2000 04
# 4  victor.lamadrid@enron.com, edward.terry@enron....   25 Sep 2000 05
#
#                                                 text day_of_week
# 0  Please Send to ETS Gas Logistics Staff (Exclud...         Tue
# 1                                                 no         Wed
# 2  Per my voicemail message to John.I talked to S...         Wed
# 3  Attached is Stikeman Elliott's derivatives upd...         Fri
# 4  FOM New Power numbers.---------------------- F...         Mon

# %%
df_enron['day_of_week'] = df_enron['day_of_week'].str.strip()

# %%
df_enron[df_enron['day_of_week']=='Sat']
# Out:
#        Unnamed: 0                        from  \
# 395           590     chris.germany@enron.com
# 411           607        pete.davis@enron.com
# 423           626  jeffrey.shankman@enron.com
# 524           791    janel.guerrero@enron.com
# 555           842    peggy.hedstrom@enron.com
# ...           ...                         ...
# 33504       48941    david.delainey@enron.com
# 33756       49305             ernie@enron.com
# 33938       49579        pete.davis@enron.com
# 33947       49593  jeffrey.shankman@enron.com
# 34016       49684       toni.graham@enron.com
#
#                                                       to             date  \
# 395                                andrea.ring@enron.com   10 Mar 2001 07
# 411                                 pete.davis@enron.com   21 Apr 2001 10
# 423                             jennifer.burns@enron.com    9 Dec 2000 06
# 524    james.steffes@enron.com, richard.shapiro@enron...   31 Mar 2001 05
# 555                                 sally.beck@enron.com    5 Aug 2000 02
# ...                                                  ...              ...
# 33504                         colleen.sullivan@enron.com   28 Oct 2000 05
# 33756                          sara.shackleton@enron.com   17 Feb 2001 23
# 33938                               pete.davis@enron.com   27 Oct 2001 12
# 33947                              harry.arora@enron.com    9 Dec 2000 06
# 34016                               sally.beck@enron.com   17 Jun 2000 11
#
#                                                     text day_of_week  \
# 395    I created deal 665150, TP2 buy from Gulf 1 at ...         Sat
# 411    Start Date: 4/21/01; HourAhead hour: 18;  No a...         Sat
# 423    put on calendar---------------------- Forwarde...         Sat
# 524    I gave Marchris my comments, but if you've got...         Sat
# 555    I wanted to update you on a few items for the ...         Sat
# ...                                                  ...         ...
# 33504  Colleen, thanks for the update - as another pa...         Sat
# 33756  You are scheduled to attend: Harassment Avoida...         Sat
# 33938  Start Date: 10/27/01; HourAhead hour: 15;  No ...         Sat
# 33947  Thanks for your help   \n\t\n\t\n\tFrom:  Harr...         Sat
# 34016  NAME\tTITLE\tDOH\tBADGE\tHR REP\tSUPERVISOR\tC...         Sat
#
#                                                    link
# 395                         chris.germany - andrea.ring
# 411                             pete.davis - pete.davis
# 423                   jeffrey.shankman - jennifer.burns
# 524    janel.guerrero - james.steffes - richard.shapiro
# 555                         peggy.hedstrom - sally.beck
# ...                                                 ...
# 33504                 david.delainey - colleen.sullivan
# 33756                           ernie - sara.shackleton
# 33938                           pete.davis - pete.davis
# 33947                    jeffrey.shankman - harry.arora
# 34016                          toni.graham - sally.beck
#
# [405 rows x 7 columns]

# %% [markdown]
# ## Task
# Take only part of email address until the @ (not important for analysis) and add a column with link (concatenation of sender and receiver).

# %%
def get_email_name(x):    
    emails = x.split(', ')
    concat_emails = ''
    if len(emails) == 1:
        return emails[0].split('@')[0]
    else:
        concat_emails = emails[0].split('@')[0] 
        for i in range(1, len(emails)):
            concat_emails += ' - ' + emails[i].split('@')[0].replace('\n\t', '')
    return concat_emails

# %%
df_enron['link'] = df_enron['from'].apply(get_email_name) + ' - ' + df_enron['to'].apply(get_email_name)
# df_enron[df_enron['link'] == 'a..bibi - sonya.johnson - dl-dji']
df_enron
# Out:
#        Unnamed: 0                       from  \
# 0               1   shelley.corman@enron.com
# 1               5      frank.ermis@enron.com
# 2               6    joan.veselack@enron.com
# 3               7  sharon.crawford@enron.com
# 4               9    chris.germany@enron.com
# ...           ...                        ...
# 34019       49691   david.delainey@enron.com
# 34020       49692   james.centilli@enron.com
# 34021       49693   charles.weldon@enron.com
# 34022       49694   vince.kaminski@enron.com
# 34023       49695  sara.shackleton@enron.com
#
#                                                       to             date  \
# 0      jean.adams@enron.com, william.aldinger@enron.c...   20 Nov 2001 15
# 1                                 mike.grigsby@enron.com   14 Feb 2001 02
# 2      jwhited@columbiaenergygroup.com, chris.germany...   22 Mar 2000 08
# 3      chris.gaffney@enron.com, mark.powell@enron.com...   27 Oct 2000 04
# 4      victor.lamadrid@enron.com, edward.terry@enron....   25 Sep 2000 05
# ...                                                  ...              ...
# 34019                             robert.virgo@enron.com    9 Feb 2001 10
# 34020                           tracy.geaccone@enron.com   17 Oct 2001 07
# 34021  bryan.hull@enron.com, a..martin@enron.com, joe...   12 Sep 2001 10
# 34022                              toni.graham@enron.com    9 Oct 2000 04
# 34023                             brent.hendry@enron.com   11 Sep 2000 02
#
#                                                     text day_of_week  \
# 0      Please Send to ETS Gas Logistics Staff (Exclud...         Tue
# 1                                                     no         Wed
# 2      Per my voicemail message to John.I talked to S...         Wed
# 3      Attached is Stikeman Elliott's derivatives upd...         Fri
# 4      FOM New Power numbers.---------------------- F...         Mon
# ...                                                  ...         ...
# 34019  Bob, please give me an update on our progress ...         Fri
# 34020  The project can not be justified, if you have ...         Wed
# 34021   -----Original Message-----From: \tSchlueter, ...         Wed
# 34022  Toni,FYI.Vince---------------------- Forwarded...         Mon
# 34023  do you want to handle?  Sara----- Forwarded by...         Mon
#
#                                                     link
# 0      shelley.corman - jean.adams - william.aldinger...
# 1                             frank.ermis - mike.grigsby
# 2      joan.veselack - jwhited - chris.germany - scot...
# 3      sharon.crawford - chris.gaffney - mark.powell ...
# 4      chris.germany - victor.lamadrid - edward.terry...
# ...                                                  ...
# 34019                      david.delainey - robert.virgo
# 34020                    james.centilli - tracy.geaccone
# 34021  charles.weldon - bryan.hull - a..martin - joe....
# 34022                       vince.kaminski - toni.graham
# 34023                     sara.shackleton - brent.hendry
#
# [34024 rows x 7 columns]

# %% [markdown]
# ## Task
# Group by the dataset on the link level (variables `from` and `to`) and create these features for each link (this is input for the networkx package):
#
# + count of mails
# + count of emails over the weekend
# + average length of text
#
# These features will be used as Edge Weights.

# %%
df_enron.groupby(['link']).size().reset_index(name='email_counts')
# Out:
#                                                     link  email_counts
# 0                     'todd'.delahoussaye - susan.bailey             1
# 1                       a..bibi - sonya.johnson - dl-dji             1
# 2      a..connor - a..connor - r..brackett - stephani...             1
# 3                            a..garcia - sara.shackleton             2
# 4                              a..gomez - louise.kitchen             1
# ...                                                  ...           ...
# 18546                          zimin.lu - vince.kaminski             2
# 18547         zimin.lu - vince.kaminski - stinson.gibner             3
# 18548                             zimin.lu - zhiyong.wei             1
# 18549               zimin.lu - zhiyong.wei - zhiyun.yang             1
# 18550  zulie.flores - marla.barnard - cynthia.barrow ...             1
#
# [18551 rows x 2 columns]

# %%
df_enron.groupby('link')['day_of_week'].apply(lambda x: (x.isin(['Sat', 'Sun'])).sum()).reset_index(name='count')
# Out:
#                                                     link  count
# 0                     'todd'.delahoussaye - susan.bailey      0
# 1                       a..bibi - sonya.johnson - dl-dji      0
# 2      a..connor - a..connor - r..brackett - stephani...      0
# 3                            a..garcia - sara.shackleton      0
# 4                              a..gomez - louise.kitchen      0
# ...                                                  ...    ...
# 18546                          zimin.lu - vince.kaminski      0
# 18547         zimin.lu - vince.kaminski - stinson.gibner      0
# 18548                             zimin.lu - zhiyong.wei      0
# 18549               zimin.lu - zhiyong.wei - zhiyun.yang      0
# 18550  zulie.flores - marla.barnard - cynthia.barrow ...      0
#
# [18551 rows x 2 columns]

# %% [markdown]
# ## SNA Analysis

# %% [markdown]
# ## Task
# Create directed graph with networkx package. use the networkx function `from_pandas_edgelist` with count of mails, count of emails over the weekend and average length of text as edge metrics. (parameter `edge_attr`)

# %% [markdown]
# ## Basic analysis: graph properties
# Find the number of nodes and edges, the average degree and the number of
# connected components

# %% [markdown]
# ### Degree distribution: find people who wrote directly to biggest number of people

# %% [markdown]
# ## Node centralities - find the top 10 people for each case

# %% [markdown]
# #### find people who could be the fastest to reach all other people

# %% [markdown]
# #### find the most important people, most information goes through them

# %% [markdown]
# #### find people who are best connected with well connected people

# %% [markdown]
# ## Communities

# %% [markdown]
# #### Cluster the users to different communities using function `k_clique_communities`

# %% [markdown]
# #### Compute clustering coefficients for each node - low clustering coefficients are in places, where network usually falls apart

# %% [markdown]
# ## (Stretch)
# ### Visualizations

# %% [markdown]
# #### visualize the network
# it might be slow on our computers with all nodes. Feel free to play around with the graph using the smaller sample of the nodes
